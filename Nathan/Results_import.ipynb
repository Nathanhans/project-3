# %%
import pandas as pd

# %%
# Presidential Results URL:  https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/VOQCHQ

results_df = pd.read_csv('./Presidential_results_2000_2020.csv')
results_df.head(10)
# Out:
#    year    state state_po county_name  county_fips        office  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# 5  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# 6  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# 7  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# 8  2000  ALABAMA       AL     BARBOUR       1005.0  US PRESIDENT
# 9  2000  ALABAMA       AL     BARBOUR       1005.0  US PRESIDENT
#
#         candidate       party  candidatevotes  totalvotes   version   mode
# 0         AL GORE    DEMOCRAT            4942       17208  20220315  TOTAL
# 1  GEORGE W. BUSH  REPUBLICAN           11993       17208  20220315  TOTAL
# ...

# %%
results_df.to_json('presidential_results.json', orient='records', lines=True)
